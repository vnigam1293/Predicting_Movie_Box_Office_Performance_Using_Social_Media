# %%
import tweepy

##followers count for directors
# Keys, tokens and secrets
consumer_key = "YnezCBGqfyEFuyKDh343clRg1"
consumer_secret = "ejPhdZIsZlWSSiBDMEcyBHpLZ8908NNcu4fj7caE8JeXI3FiKG"
access_token = "959126259480629248-55N1tE4AORNv2CQmhtXS6N2uzeRrzYs"
access_token_secret = "xRUMka4vO27JMlT91o9mHExSulaVZ9aSNrGwzdEseiBvv"

# Tweepy OAuthHandler
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# All your targets here
targets = ["josierourke", "TisAnneFletcher", "CorbetBrady", "plhedges", "pramsey342", "RiversC_", "ClintEastwoodLA",
           "alfonsocuaron", "BrianKenMiller", "NadineLabaki", "Robmarshalluk", "creepypuppet", "travisbknight", "ppawlikowski41",
           "etanjc", "aanandlrai", "GhostPanther", "mimi_leder", "AdamRobitel", "pumbaaguy1", "NeilBurger", "CharlesM_Smith", "MNightShyamalan",
           "lukasdhont", "_nbc_", "MysteryGuitarM", "C_Hardwicke", "asgharfarhadi", "iammikemitchell", "adamshankman", "NMcCarthyPiano", 
           "Rodriguez", "StephenMerchant", "straussschulson", "creetureshow", "DeanDeBlois", "iamjamiefoxx"] 

#with open("targetNames.txt") as file:
#    targets = [line.strip() for line in file]

for target in targets:
    user = api.get_user(target)
    print(user.name, user.followers_count)
    
#user_objs = api.lookup_users(user_ids=target)
#    print(user.screen_name)
# Out:
# Josie Rourke 23884
# Anne Fletcher 152
# brady corbet 225
# peter hedges 5
# Peter Ramsey 4893
# Christian Rivers 178
# Clint Eastwood🇺🇸 73089
# Alfonso Cuaron 120251
# Brian Miller 3136
# Nadine Labaki 740833
# Rob Marshall 331
# James Wan 211653
# Travis Knight 686
# Paweł Pawlikowski 1
# Etan Cohen 4384
# AANAND L RAI 151492
# Adam McKay 1014175
# Mimi Leder 438
# AdamRobitel 8671
# Tony Bancroft 8580
# Neil Burger 8407
# Charles Martin Smith 338
# M. Night Shyamalan 155683
# Lukas Dhont 317
# Nuri Bilge Ceylan 478882
# Joe Penna 239636
# Catherine Hardwicke 16986
# asghar farhadi 264
# Mike Mitchell 67412
# Adamshankman 1360
# Nicholas McCarthy 16150
# Robert Rodriguez 314810
# Stephen Merchant 623571
# Todd Strauss-Schulso 5199
# christopher landon 1547
# Dean DeBlois 13391
# Jamie Foxx 4702043

# %%
import tweepy

##followers count for actor
# Keys, tokens and secrets
consumer_key = "YnezCBGqfyEFuyKDh343clRg1"
consumer_secret = "ejPhdZIsZlWSSiBDMEcyBHpLZ8908NNcu4fj7caE8JeXI3FiKG"
access_token = "959126259480629248-55N1tE4AORNv2CQmhtXS6N2uzeRrzYs"
access_token_secret = "xRUMka4vO27JMlT91o9mHExSulaVZ9aSNrGwzdEseiBvv"

# Tweepy OAuthHandler
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# All your targets here
targets = ["DoctorCant", "DLMacdonald19", "LHedgesUpdates", "hugoweaving_rs", "ClintEastwoodLA", "TheSlyStallone", "JASONMOMOA_TH",
           "TherouxDaily", "TomaszTomaszKot", "WillFerrell", "SteveCarell", "iamsrk", "MiloVentimiglia", "msalisonpill", "TherouxDaily",
           "Toby_Kebbell", "TyLabine", "DannyDeVito", "mrkreeves", "BryanCranston", "VoiceOfVegeta", "BruceyWillis",
           "muratcemcir", "theofficialmads", "AnthonyMackie", "TheLiamNeeson", "BardemAntarctic", "ColmFeore", "TheRock",
           "GerardButler", "RobertDowneyJr"] 

#with open("targetNames.txt") as file:
#    targets = [line.strip() for line in file]

for target in targets:
    user = api.get_user(target)
    print(user.name, user.followers_count)
    
#user_objs = api.lookup_users(user_ids=target)
#    print(user.screen_name)
# Out:
# Richard Cant 69
# Danielle Macdonald 2274
# Lucas Hedges Updates 459
# Hugo Weaving | RS 2752
# Clint Eastwood🇺🇸 73092
# Sylvester Stallone 2801180
# Jason Momoa 16450
# Justin Theroux Daily 2021
# Tomasz Kot 14
# Will Ferrell 10008
# Steve Carell 5606341
# Shah Rukh Khan 36877567
# Milo Ventimiglia 586173
# Alison Pill 146
# Justin Theroux Daily 2021
# Toby Kebbell 1321
# Tyler Labine 51576
# Danny DeVito 3973491
# Keanu Reeves 5338
# Bryan Cranston 2126444
# Christopher Sabat 158384
# Bruce Willis 50342
# murat cemcir 1219838
# Mads Mikkelsen Official 87027
# Anthony Mackie 794300
# Liam Neeson 3314
# Javier Bardem 21209
# Colm Feore 1609
# Dwayne Johnson 13029220
# Gerard Butler 523591
# Robert Downey Jr 11962102

# %%
import tweepy

##followers count for actress
# Keys, tokens and secrets
consumer_key = "YnezCBGqfyEFuyKDh343clRg1"
consumer_secret = "ejPhdZIsZlWSSiBDMEcyBHpLZ8908NNcu4fj7caE8JeXI3FiKG"
access_token = "959126259480629248-55N1tE4AORNv2CQmhtXS6N2uzeRrzYs"
access_token_secret = "xRUMka4vO27JMlT91o9mHExSulaVZ9aSNrGwzdEseiBvv"

# Tweepy OAuthHandler
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# All your targets here
targets = ["JenniferAnnistn", "natpdotcom", "JuliaRoberts", "HaileeSteinfeld", "HeraHilmar", "YalitzaAparicio", "EMortimer",
           "realamberheard", "HaileeSteinfeld", "kulig_joanna", "eizamusica", "KatrinaKaifFB", "VanessaHudgens", "TheAmy_Adams",
           "jonesfelicity", "NicoleKidman", "DeborahAnnWoll", "EMortimer", "aliceeveupdate", "NicoleKidman", "BryceDHoward",
           "CooksonSophie", "anyataylorjoy", "msdiane_lane", "MaraThelmaa", "HereIsGina", "emmyrossum", "PenelopeCruz1",
           "MargotRobbie", "wendimclendonco", "TaySchilling", "eizamusica", "Florence_Pugh", "priyankachopra", "jessica_rothe",
           "CateEBlanchett"] 

#with open("targetNames.txt") as file:
#    targets = [line.strip() for line in file]

for target in targets:
    user = api.get_user(target)
    print(user.name, user.followers_count)
    
#user_objs = api.lookup_users(user_ids=target)
#    print(user.screen_name)
# Out:
# Jennifer Aniston 39138
# NataliePortman.com 44788
# Julia Roberts 517380
# Hailee Steinfeld 1032458
# Hera Hilmar 4324
# Yalitza Aparicio Martínez 38636
# Emily Mortimer 9279
# Amber Heard 73713
# Hailee Steinfeld 1032458
# Joanna Kulig 137
# Eiza Gonzalez Reyna 1429836
# Katrina Kaif Online 1847777
# Vanessa Hudgens 7232662
# Amy Adams 2465
# Felicity Jones News 19225
# Nicole Kidman 77369
# Deborah Ann Woll 242207
# Emily Mortimer 9279
# Alice Eve 624
# Nicole Kidman 77369
# Bryce Dallas Howard 196394
# Sophie Cookson 41888
# Anya Taylor Joy 47739
# Diane Lane 1592
# María Thelma 8
# Gina Rodriguez 497777
# Emmy Rossum 873979
# Penélope Cruz FanPage 513
# Margot Robbie 1119942
# Wendi McLendon-Covey 140374
# Taylor Schilling 662214
# Eiza Gonzalez Reyna 1429836
# Florence Pugh 18230
# PRIYANKA 23700666
# Jessica Rothe 10650
# Cate Blanchett 3299
