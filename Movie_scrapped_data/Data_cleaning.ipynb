# %%
import pandas as pd
import csv

# %%
m2
# Out:
#       2018-11-23 10:38:04  \
# 0     2018-11-23 09:58:37
# 1     2018-11-23 09:43:15
# 2     2018-11-23 09:43:07
# 3     2018-11-23 09:42:00
# 4     2018-11-23 09:42:00
# 5     2018-11-23 07:37:50
# 6     2018-11-23 06:26:43
# 7     2018-11-23 05:45:45
# 8     2018-11-23 03:37:27
# 9     2018-11-23 03:35:23
# 10    2018-11-23 03:06:09
# 11    2018-11-23 02:45:09
# 12    2018-11-23 02:15:52
# 13    2018-11-23 01:51:17
# 14    2018-11-23 01:50:49
# 15    2018-11-23 01:45:11
# 16    2018-11-23 01:43:25
# 17    2018-11-23 01:38:16
# 18    2018-11-23 01:37:26
# 19    2018-11-23 01:20:12
# 20    2018-11-23 01:13:58
# 21    2018-11-23 00:25:13
# 22    2018-11-23 00:02:50
# 23    2018-11-22 23:41:43
# 24    2018-11-22 23:07:15
# 25    2018-11-22 20:37:42
# 26    2018-11-22 20:35:05
# 27    2018-11-22 20:27:23
# 28    2018-11-22 20:22:06
# 29    2018-11-22 19:28:24
# ...                   ...
# 1247  2018-11-13 06:41:13
# 1248  2018-11-13 06:19:44
# 1249  2018-11-13 06:19:04
# ...

# %%
m2_r2 = m2.drop(m2.columns[[0]], axis=1)

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
print(m2_r2)
# Out:
#      b'RT @HistoryScotland: The making of a French queen of Scots - new guest blog from @HistoryRoyalWmn charts the formative years of #MaryQueeno\xe2\x80\xa6'
# 0     b'RT @HistoryScotland: The making of a French ...
# 1     b'RT @ScotMemories: The making of a French que...
# 2     b'RT @HistoryScotland: The making of a French ...
# 3     b'The making of a French queen of Scots - new ...
# 4     b'The making of a French queen of Scots - new ...
# 5     b'RT @popcornreel: What a wonderful movie MARY...
# 6     b'RT @archivesaoirse: New still. #MaryQueenofS...
# 7     b'RT @archivesaoirse: New still. #MaryQueenofS...
# 8     b"RT @HMHbooks: If you thought your family was...
# 9     b'RT @MaryQueenMovie: A friendship that became...
# 10    b'RT @archivesaoirse: New still. #MaryQueenofS...
# 11    b'#GirlPower #Trivia Night, presented by @Mary...
# 12    b'RT @archivesaoirse: New still. #MaryQueenofS...
# 13    b'RT @archivesaoirse: New still. #MaryQueenofS...
# ...

# %%
import nltk, csv, numpy 
from nltk import sent_tokenize, word_tokenize, pos_tag
reader = csv.reader(open('m2_r2.csv'), delimiter= ",")
tokenData = nltk.word_tokenize(reader)

with open("m2_r2.csv") as csvfile:
tokenData = nltk.word_tokenize(reader)
# Out:
#   File "<ipython-input-25-8bd8d30e87d5>", line 7
#     tokenData = nltk.word_tokenize(reader)
#             ^
# IndentationError: expected an indented block

# %%
text = nltk.corpus.raw(m2_r2)
tokens = nltk.word_tokenize(text)
cwords = [w.lower() for w in tokens]
len(cwords)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-53771e277e4a> in <module>()
# ----> 1 text = nltk.corpus.raw(m2_r2)
#       2 tokens = nltk.word_tokenize(text)
#       3 cwords = [w.lower() for w in tokens]
#       4 len(cwords)
#
# /anaconda3/lib/python3.6/site-packages/nltk/lazyimport.py in __getattr__(self, name)
#     120                   'Module load triggered by attribute %r read access' % name)
#     121         module = self.__lazymodule_import()
# --> 122         return getattr(module, name)
#     123
#     124     def __setattr__(self, name, value):
#
# AttributeError: module 'nltk.corpus' has no attribute 'raw'

# %%
type(m2_r2)
# Out:
# pandas.core.frame.DataFrame

# %%
with open('missBala.csv') as outcsv:
    writer = csv.writer(outcsv)
    writer.writerow(["Tweet"])
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-31-632ef9b5e3e8> in <module>()
#       1 with open('missBala.csv') as outcsv:
#       2     writer = csv.writer(outcsv)
# ----> 3     writer.writerow(["Tweet"])
#
# UnsupportedOperation: not writable
